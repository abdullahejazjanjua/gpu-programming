# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/gpu-programming
# %cd vectorAdd
# %ls
# Out:
# /content/drive/MyDrive/gpu-programming
# /content/drive/MyDrive/gpu-programming/vectorAdd
# main.cpp  vectorAdd.cu  vectorAdd.h

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# Sun Feb  1 15:39:51 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# ...

# %%
# !nvcc -arch=sm_75 vectorAdd.cu main.cpp -o vectorAdd
# !ls
# Out:
# main.cpp  vectorAdd  vectorAdd.cu  vectorAdd.h

# %%
# !g++ vectorAdd main.cpp -o out.exe

# %%
# !./vectorAdd
# Out:
# A[0] (2.13039) + B[0] (2.13039) = C[0] (4.26077)
# A[1] (0.980787) + B[1] (0.980787) = C[1] (1.96157)
# A[2] (4.61474) + B[2] (4.61474) = C[2] (9.22947)
# A[3] (0.436357) + B[3] (0.436357) = C[3] (0.872715)
# A[4] (0.501426) + B[4] (0.501426) = C[4] (1.00285)
# A[5] (0.759134) + B[5] (0.759134) = C[5] (1.51827)
# A[6] (0.710526) + B[6] (0.710526) = C[6] (1.42105)
# A[7] (1.03933) + B[7] (1.03933) = C[7] (2.07866)
# A[8] (0.88626) + B[8] (0.88626) = C[8] (1.77252)
# A[9] (0.233295) + B[9] (0.233295) = C[9] (0.466589)
